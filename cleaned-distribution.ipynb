# %%
import pandas as pd
import numpy as np
from IPython.display import HTML
import base64

# %%
# Load the raw distribution data
df_dist = pd.read_csv(r"C:\Users\bukky\bakery_chain\bakery_chain\raw dataset\dirty_distribution.csv")

# Preview the first few rows
df_dist.head(30)
# Out:
#    Branch ID  Order ID Delivery Date  Delivery Time (Hours) Route ID  \
# 0        B04         1    2024-03-23                      2       R4
# 1        B04         2    2024-05-04                      5       R2
# 2        B02         3    2024-04-14                      6       R5
# 3        B02         4    2024-05-04                      2       R3
# 4        B02         5    2024-06-30                     -5       R5
# 5        B01         6    2024-06-10                      2       R5
# 6        B01         7    2024-03-08                      3       R2
# 7        B04         8    2024-06-27                      7       R4
# 8        B04         9    2024-04-11                      6       R4
# 9        B02        10    2024-05-31                      2       R2
# 10       B02        11    2024-03-22                      2       R4
# 11       B02        12    2024-01-16                      3       R5
# 12       B02        13    2024-06-06                      3       R4
# 13       B03        14    2024-04-06                      4       R1
# 14       B04        15    2024-03-30                      7       R3
# 15       B02        16    2024-04-10                      3       R1
# 16       B04        17    2024-03-28                      7       R3
# 17       B02        18    2024-05-05                      2       R2
# 18       B02        19    2024-04-05                      5       R2
# 19       B01        20    2024-03-08                      3       R2
# 20       B01        21    2024-02-14                      5       R4
# 21       B03        22    2024-04-18                      6       R3
# 22       B04        23    2024-06-25                      3       R1
# 23       B02        24    2024-04-22                      5       R1
# 24       B02        25    2024-03-14                      4       R3
# 25       B02        26    2024-06-10                      3       R3
# 26       B02        27    2024-05-16                      3       R2
# 27       B01        28    2024-05-27                      5       R1
# 28       B04        29    2024-03-09                      6       R3
# 29       B01        30    2024-03-25                      3       R4
#
#     Transportation Cost ($) Customer Location
# 0                      91.0          Mesa, AZ
# 1                      44.0      Tolleson, AZ
# 2                      48.0     Bradenton, FL
# 3                      69.0      Savannah, GA
# 4                      42.0     Bradenton, FL
# 5                      69.0       Modesto, CA
# 6                     101.0    Birmingham, AL
# 7                      64.0    Birmingham, AL
# 8                      74.0               NaN
# 9                     100.0      Tolleson, AZ
# 10                      NaN      Savannah, GA
# 11                    108.0     Bradenton, FL
# 12                    113.0     Texarkana, AR
# 13                     73.0          Mesa, AZ
# 14                     52.0    Birmingham, AL
# 15                     63.0          Mesa, AZ
# 16                     99.0     Bradenton, FL
# 17                    115.0    Villa Rica, GA
# 18                     50.0    Batesville, AR
# 19                     57.0          Mesa, AZ
# 20                     85.0      Tolleson, AZ
# 21                     69.0     Texarkana, AR
# 22                    112.0    Birmingham, AL
# 23                     58.0          Mesa, AZ
# 24                     66.0     Texarkana, AR
# 25                    101.0    Birmingham, AL
# 26                     68.0    Batesville, AR
# 27                     72.0    Birmingham, AL
# 28                     55.0    Batesville, AR
# 29                    111.0          Mesa, AZ

# %%
# View column names and data types
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch ID                601 non-null    object
#  1   Order ID                 601 non-null    int64
#  2   Delivery Date            601 non-null    object
#  3   Delivery Time (Hours)    601 non-null    int64
#  4   Route ID                 601 non-null    object
#  5   Transportation Cost ($)  600 non-null    float64
#  6   Customer Location        600 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 33.0+ KB

# %%
# View summary statistics
df_dist.describe(include='all')
# Out:
#        Branch ID    Order ID Delivery Date  Delivery Time (Hours) Route ID  \
# count        601  601.000000           601             601.000000      601
# unique         4         NaN           176                    NaN        5
# top          B02         NaN    2024-03-21                    NaN       R2
# freq         162         NaN             9                    NaN      138
# mean         NaN  300.004992           NaN               4.387687      NaN
# std          NaN  173.629438           NaN               1.746744      NaN
# min          NaN    1.000000           NaN              -5.000000      NaN
# 25%          NaN  150.000000           NaN               3.000000      NaN
# 50%          NaN  300.000000           NaN               4.000000      NaN
# 75%          NaN  450.000000           NaN               6.000000      NaN
# max          NaN  600.000000           NaN               7.000000      NaN
#
#         Transportation Cost ($) Customer Location
# count                600.000000               600
# unique                      NaN                10
# top                         NaN    Villa Rica, GA
# freq                        NaN                75
# mean                  80.605000               NaN
# std                   22.493159               NaN
# min                   40.000000               NaN
# 25%                   62.000000               NaN
# 50%                   80.000000               NaN
# 75%                  100.250000               NaN
# max                  119.000000               NaN

# %%
# Rename to snake_case for easier handling
df_dist.rename(columns={
    "Branch ID": "branch_id",
    "Order ID": "order_id",
    "Delivery Date": "delivery_date",
    "Delivery Time (Hours)": "delivery_time_hours",
    "Route ID": "route_id",
    "Transportation Cost ($)": "transportation_cost",
    "Customer Location": "customer_location"
}, inplace=True)

# %%
df_dist.columns
# Out:
# Index(['branch_id', 'order_id', 'delivery_date', 'delivery_time_hours',
#        'route_id', 'transportation_cost', 'customer_location'],
#       dtype='object')

# %%
# Convert delivery_date to datetime format
df_dist["delivery_date"] = pd.to_datetime(df_dist["delivery_date"], errors='coerce')

# %%
# View column names and data types
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   branch_id            601 non-null    object
#  1   order_id             601 non-null    int64
#  2   delivery_date        601 non-null    datetime64[ns]
#  3   delivery_time_hours  601 non-null    int64
#  4   route_id             601 non-null    object
#  5   transportation_cost  600 non-null    float64
#  6   customer_location    600 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 33.0+ KB

# %%
# Replace negative delivery times with NaN
df_dist["delivery_time_hours"] = df_dist["delivery_time_hours"].apply(lambda x: x if x >= 0 else np.nan)

# %%
# Preview the first few rows
df_dist.head(30)
# Out:
#    branch_id  order_id delivery_date  delivery_time_hours route_id  \
# 0        B04         1    2024-03-23                  2.0       R4
# 1        B04         2    2024-05-04                  5.0       R2
# 2        B02         3    2024-04-14                  6.0       R5
# 3        B02         4    2024-05-04                  2.0       R3
# 4        B02         5    2024-06-30                  NaN       R5
# 5        B01         6    2024-06-10                  2.0       R5
# 6        B01         7    2024-03-08                  3.0       R2
# 7        B04         8    2024-06-27                  7.0       R4
# 8        B04         9    2024-04-11                  6.0       R4
# 9        B02        10    2024-05-31                  2.0       R2
# 10       B02        11    2024-03-22                  2.0       R4
# 11       B02        12    2024-01-16                  3.0       R5
# 12       B02        13    2024-06-06                  3.0       R4
# 13       B03        14    2024-04-06                  4.0       R1
# 14       B04        15    2024-03-30                  7.0       R3
# 15       B02        16    2024-04-10                  3.0       R1
# 16       B04        17    2024-03-28                  7.0       R3
# 17       B02        18    2024-05-05                  2.0       R2
# 18       B02        19    2024-04-05                  5.0       R2
# 19       B01        20    2024-03-08                  3.0       R2
# 20       B01        21    2024-02-14                  5.0       R4
# 21       B03        22    2024-04-18                  6.0       R3
# 22       B04        23    2024-06-25                  3.0       R1
# 23       B02        24    2024-04-22                  5.0       R1
# 24       B02        25    2024-03-14                  4.0       R3
# 25       B02        26    2024-06-10                  3.0       R3
# 26       B02        27    2024-05-16                  3.0       R2
# 27       B01        28    2024-05-27                  5.0       R1
# 28       B04        29    2024-03-09                  6.0       R3
# 29       B01        30    2024-03-25                  3.0       R4
#
#     transportation_cost customer_location
# 0                  91.0          Mesa, AZ
# 1                  44.0      Tolleson, AZ
# 2                  48.0     Bradenton, FL
# 3                  69.0      Savannah, GA
# 4                  42.0     Bradenton, FL
# 5                  69.0       Modesto, CA
# 6                 101.0    Birmingham, AL
# 7                  64.0    Birmingham, AL
# 8                  74.0               NaN
# 9                 100.0      Tolleson, AZ
# 10                  NaN      Savannah, GA
# 11                108.0     Bradenton, FL
# 12                113.0     Texarkana, AR
# 13                 73.0          Mesa, AZ
# 14                 52.0    Birmingham, AL
# 15                 63.0          Mesa, AZ
# 16                 99.0     Bradenton, FL
# 17                115.0    Villa Rica, GA
# 18                 50.0    Batesville, AR
# 19                 57.0          Mesa, AZ
# 20                 85.0      Tolleson, AZ
# 21                 69.0     Texarkana, AR
# 22                112.0    Birmingham, AL
# 23                 58.0          Mesa, AZ
# 24                 66.0     Texarkana, AR
# 25                101.0    Birmingham, AL
# 26                 68.0    Batesville, AR
# 27                 72.0    Birmingham, AL
# 28                 55.0    Batesville, AR
# 29                111.0          Mesa, AZ

# %%
# Calculate the median delivery time (excluding NaNs)
median_delivery_time = df_dist["delivery_time_hours"].median()

# Replace NaN values with the median
df_dist["delivery_time_hours"] = df_dist["delivery_time_hours"].fillna(median_delivery_time)

# %%
# Preview the first few rows
df_dist.head(30)
# Out:
#    branch_id  order_id delivery_date  delivery_time_hours route_id  \
# 0        B04         1    2024-03-23                  2.0       R4
# 1        B04         2    2024-05-04                  5.0       R2
# 2        B02         3    2024-04-14                  6.0       R5
# 3        B02         4    2024-05-04                  2.0       R3
# 4        B02         5    2024-06-30                  4.0       R5
# 5        B01         6    2024-06-10                  2.0       R5
# 6        B01         7    2024-03-08                  3.0       R2
# 7        B04         8    2024-06-27                  7.0       R4
# 8        B04         9    2024-04-11                  6.0       R4
# 9        B02        10    2024-05-31                  2.0       R2
# 10       B02        11    2024-03-22                  2.0       R4
# 11       B02        12    2024-01-16                  3.0       R5
# 12       B02        13    2024-06-06                  3.0       R4
# 13       B03        14    2024-04-06                  4.0       R1
# 14       B04        15    2024-03-30                  7.0       R3
# 15       B02        16    2024-04-10                  3.0       R1
# 16       B04        17    2024-03-28                  7.0       R3
# 17       B02        18    2024-05-05                  2.0       R2
# 18       B02        19    2024-04-05                  5.0       R2
# 19       B01        20    2024-03-08                  3.0       R2
# 20       B01        21    2024-02-14                  5.0       R4
# 21       B03        22    2024-04-18                  6.0       R3
# 22       B04        23    2024-06-25                  3.0       R1
# 23       B02        24    2024-04-22                  5.0       R1
# 24       B02        25    2024-03-14                  4.0       R3
# 25       B02        26    2024-06-10                  3.0       R3
# 26       B02        27    2024-05-16                  3.0       R2
# 27       B01        28    2024-05-27                  5.0       R1
# 28       B04        29    2024-03-09                  6.0       R3
# 29       B01        30    2024-03-25                  3.0       R4
#
#     transportation_cost customer_location
# 0                  91.0          Mesa, AZ
# 1                  44.0      Tolleson, AZ
# 2                  48.0     Bradenton, FL
# 3                  69.0      Savannah, GA
# 4                  42.0     Bradenton, FL
# 5                  69.0       Modesto, CA
# 6                 101.0    Birmingham, AL
# 7                  64.0    Birmingham, AL
# 8                  74.0               NaN
# 9                 100.0      Tolleson, AZ
# 10                  NaN      Savannah, GA
# 11                108.0     Bradenton, FL
# 12                113.0     Texarkana, AR
# 13                 73.0          Mesa, AZ
# 14                 52.0    Birmingham, AL
# 15                 63.0          Mesa, AZ
# 16                 99.0     Bradenton, FL
# 17                115.0    Villa Rica, GA
# 18                 50.0    Batesville, AR
# 19                 57.0          Mesa, AZ
# 20                 85.0      Tolleson, AZ
# 21                 69.0     Texarkana, AR
# 22                112.0    Birmingham, AL
# 23                 58.0          Mesa, AZ
# 24                 66.0     Texarkana, AR
# 25                101.0    Birmingham, AL
# 26                 68.0    Batesville, AR
# 27                 72.0    Birmingham, AL
# 28                 55.0    Batesville, AR
# 29                111.0          Mesa, AZ

# %%
#Convert delivery_time_hours to int
df_dist["delivery_time_hours"] = df_dist["delivery_time_hours"].astype("Int64")

# %%
# Preview the first few rows
df_dist.head(30)
# Out:
#    branch_id  order_id delivery_date  delivery_time_hours route_id  \
# 0        B04         1    2024-03-23                    2       R4
# 1        B04         2    2024-05-04                    5       R2
# 2        B02         3    2024-04-14                    6       R5
# 3        B02         4    2024-05-04                    2       R3
# 4        B02         5    2024-06-30                    4       R5
# 5        B01         6    2024-06-10                    2       R5
# 6        B01         7    2024-03-08                    3       R2
# 7        B04         8    2024-06-27                    7       R4
# 8        B04         9    2024-04-11                    6       R4
# 9        B02        10    2024-05-31                    2       R2
# 10       B02        11    2024-03-22                    2       R4
# 11       B02        12    2024-01-16                    3       R5
# 12       B02        13    2024-06-06                    3       R4
# 13       B03        14    2024-04-06                    4       R1
# 14       B04        15    2024-03-30                    7       R3
# 15       B02        16    2024-04-10                    3       R1
# 16       B04        17    2024-03-28                    7       R3
# 17       B02        18    2024-05-05                    2       R2
# 18       B02        19    2024-04-05                    5       R2
# 19       B01        20    2024-03-08                    3       R2
# 20       B01        21    2024-02-14                    5       R4
# 21       B03        22    2024-04-18                    6       R3
# 22       B04        23    2024-06-25                    3       R1
# 23       B02        24    2024-04-22                    5       R1
# 24       B02        25    2024-03-14                    4       R3
# 25       B02        26    2024-06-10                    3       R3
# 26       B02        27    2024-05-16                    3       R2
# 27       B01        28    2024-05-27                    5       R1
# 28       B04        29    2024-03-09                    6       R3
# 29       B01        30    2024-03-25                    3       R4
#
#     transportation_cost customer_location
# 0                  91.0          Mesa, AZ
# 1                  44.0      Tolleson, AZ
# 2                  48.0     Bradenton, FL
# 3                  69.0      Savannah, GA
# 4                  42.0     Bradenton, FL
# 5                  69.0       Modesto, CA
# 6                 101.0    Birmingham, AL
# 7                  64.0    Birmingham, AL
# 8                  74.0               NaN
# 9                 100.0      Tolleson, AZ
# 10                  NaN      Savannah, GA
# 11                108.0     Bradenton, FL
# 12                113.0     Texarkana, AR
# 13                 73.0          Mesa, AZ
# 14                 52.0    Birmingham, AL
# 15                 63.0          Mesa, AZ
# 16                 99.0     Bradenton, FL
# 17                115.0    Villa Rica, GA
# 18                 50.0    Batesville, AR
# 19                 57.0          Mesa, AZ
# 20                 85.0      Tolleson, AZ
# 21                 69.0     Texarkana, AR
# 22                112.0    Birmingham, AL
# 23                 58.0          Mesa, AZ
# 24                 66.0     Texarkana, AR
# 25                101.0    Birmingham, AL
# 26                 68.0    Batesville, AR
# 27                 72.0    Birmingham, AL
# 28                 55.0    Batesville, AR
# 29                111.0          Mesa, AZ

# %%
# View column names and data types
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   branch_id            601 non-null    object
#  1   order_id             601 non-null    int64
#  2   delivery_date        601 non-null    datetime64[ns]
#  3   delivery_time_hours  601 non-null    Int64
#  4   route_id             601 non-null    object
#  5   transportation_cost  600 non-null    float64
#  6   customer_location    600 non-null    object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 33.6+ KB

# %%
# Fill missing transportation cost with the median
df_dist["transportation_cost"] = df_dist["transportation_cost"].fillna(df_dist["transportation_cost"].median())

# %%
# View column names and data types
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   branch_id            601 non-null    object
#  1   order_id             601 non-null    int64
#  2   delivery_date        601 non-null    datetime64[ns]
#  3   delivery_time_hours  601 non-null    Int64
#  4   route_id             601 non-null    object
#  5   transportation_cost  601 non-null    float64
#  6   customer_location    600 non-null    object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 33.6+ KB

# %%
# Fill missing customer location with most frequent location
most_common_location = df_dist["customer_location"].mode()[0]
df_dist["customer_location"] = df_dist["customer_location"].fillna(most_common_location)

# %%
# Preview the first few rows
df_dist.head(30)
# Out:
#    branch_id  order_id delivery_date  delivery_time_hours route_id  \
# 0        B04         1    2024-03-23                    2       R4
# 1        B04         2    2024-05-04                    5       R2
# 2        B02         3    2024-04-14                    6       R5
# 3        B02         4    2024-05-04                    2       R3
# 4        B02         5    2024-06-30                    4       R5
# 5        B01         6    2024-06-10                    2       R5
# 6        B01         7    2024-03-08                    3       R2
# 7        B04         8    2024-06-27                    7       R4
# 8        B04         9    2024-04-11                    6       R4
# 9        B02        10    2024-05-31                    2       R2
# 10       B02        11    2024-03-22                    2       R4
# 11       B02        12    2024-01-16                    3       R5
# 12       B02        13    2024-06-06                    3       R4
# 13       B03        14    2024-04-06                    4       R1
# 14       B04        15    2024-03-30                    7       R3
# 15       B02        16    2024-04-10                    3       R1
# 16       B04        17    2024-03-28                    7       R3
# 17       B02        18    2024-05-05                    2       R2
# 18       B02        19    2024-04-05                    5       R2
# 19       B01        20    2024-03-08                    3       R2
# 20       B01        21    2024-02-14                    5       R4
# 21       B03        22    2024-04-18                    6       R3
# 22       B04        23    2024-06-25                    3       R1
# 23       B02        24    2024-04-22                    5       R1
# 24       B02        25    2024-03-14                    4       R3
# 25       B02        26    2024-06-10                    3       R3
# 26       B02        27    2024-05-16                    3       R2
# 27       B01        28    2024-05-27                    5       R1
# 28       B04        29    2024-03-09                    6       R3
# 29       B01        30    2024-03-25                    3       R4
#
#     transportation_cost customer_location
# 0                  91.0          Mesa, AZ
# 1                  44.0      Tolleson, AZ
# 2                  48.0     Bradenton, FL
# 3                  69.0      Savannah, GA
# 4                  42.0     Bradenton, FL
# 5                  69.0       Modesto, CA
# 6                 101.0    Birmingham, AL
# 7                  64.0    Birmingham, AL
# 8                  74.0    Villa Rica, GA
# 9                 100.0      Tolleson, AZ
# 10                 80.0      Savannah, GA
# 11                108.0     Bradenton, FL
# 12                113.0     Texarkana, AR
# 13                 73.0          Mesa, AZ
# 14                 52.0    Birmingham, AL
# 15                 63.0          Mesa, AZ
# 16                 99.0     Bradenton, FL
# 17                115.0    Villa Rica, GA
# 18                 50.0    Batesville, AR
# 19                 57.0          Mesa, AZ
# 20                 85.0      Tolleson, AZ
# 21                 69.0     Texarkana, AR
# 22                112.0    Birmingham, AL
# 23                 58.0          Mesa, AZ
# 24                 66.0     Texarkana, AR
# 25                101.0    Birmingham, AL
# 26                 68.0    Batesville, AR
# 27                 72.0    Birmingham, AL
# 28                 55.0    Batesville, AR
# 29                111.0          Mesa, AZ

# %%
# Drop exact duplicate rows if any
df_dist = df_dist.drop_duplicates()

# %%
# View column names and data types
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   branch_id            600 non-null    object
#  1   order_id             600 non-null    int64
#  2   delivery_date        600 non-null    datetime64[ns]
#  3   delivery_time_hours  600 non-null    Int64
#  4   route_id             600 non-null    object
#  5   transportation_cost  600 non-null    float64
#  6   customer_location    600 non-null    object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 38.1+ KB

# %%
def create_download_link(df_dist, filename="cleaned_distribution.csv"):
    csv = df_dist.to_csv(index=False)
    b64 = base64.b64encode(csv.encode()).decode()
    return HTML(f'<a download="{filename}" href="data:text/csv;base64,{b64}">Download CSV</a>')

create_download_link(df_dist)
# Out:
# <a download="cleaned_distribution.csv" href="data:text/csv;base64,...">Download CSV</a>
